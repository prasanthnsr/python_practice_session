# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from pandas import Series

# %%
# Titanic Positive Case - Without any Mismatch Records

titanic_positive_source = "D:\\Projects\\Cadent\\Cadent_BigDataTesting_Automation\\Demo\\Script_without_UDF\\Data_Files\\Titanic\\Titanic_Input\\Titanic_PositiveCase_Source.xls"
titanic_positive_target = "D:\\Projects\\Cadent\\Cadent_BigDataTesting_Automation\\Demo\\Script_without_UDF\\Data_Files\\Titanic\\Titanic_Input\\Titanic_PositiveCase_Target.xls"
titanic_positive_mismatch = "D:\\Projects\\Cadent\\Cadent_BigDataTesting_Automation\\Demo\\Script_without_UDF\\Data_Files\\Titanic\\Titanic_Output\\Titanic_PositiveCase_Mismatch.xls"

# %%
# Reading 'Source' data

source_p = pd.read_excel(titanic_positive_source, sheet_name = 'titanic')
print(source_p)
# Out:
#        pid  pclass  survived                                             name  \
# 0        1       1         1                    Allen, Miss. Elisabeth Walton
# 1        2       1         1                   Allison, Master. Hudson Trevor
# 2        3       1         0                     Allison, Miss. Helen Loraine
# 3        4       1         0             Allison, Mr. Hudson Joshua Creighton
# 4        5       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...    ...     ...       ...                                              ...
# 1304  1305       3         0                             Zabour, Miss. Hileni
# 1305  1306       3         0                            Zabour, Miss. Thamine
# 1306  1307       3         0                        Zakarian, Mr. Mapriededer
# 1307  1308       3         0                              Zakarian, Mr. Ortin
# 1308  1309       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 15 columns]

# %%
# Reading 'Target' data

target_p = pd.read_excel(titanic_positive_target, sheet_name = 'titanic')
print(target_p)
# Out:
#        pid  pclass  survived                                             name  \
# 0        1       1         1                    Allen, Miss. Elisabeth Walton
# 1        2       1         1                   Allison, Master. Hudson Trevor
# 2        3       1         0                     Allison, Miss. Helen Loraine
# 3        4       1         0             Allison, Mr. Hudson Joshua Creighton
# 4        5       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...    ...     ...       ...                                              ...
# 1304  1305       3         0                             Zabour, Miss. Hileni
# 1305  1306       3         0                            Zabour, Miss. Thamine
# 1306  1307       3         0                        Zakarian, Mr. Mapriededer
# 1307  1308       3         0                              Zakarian, Mr. Ortin
# 1308  1309       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 15 columns]

# %%
# Common Records accross Source & Target

source_target_common_p = source_p.merge(target_p, how = 'inner' ,indicator=False)
source_target_common_p
# Out:
#        pid  pclass  survived                                             name  \
# 0        1       1         1                    Allen, Miss. Elisabeth Walton
# 1        2       1         1                   Allison, Master. Hudson Trevor
# 2        3       1         0                     Allison, Miss. Helen Loraine
# 3        4       1         0             Allison, Mr. Hudson Joshua Creighton
# 4        5       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...    ...     ...       ...                                              ...
# 1304  1305       3         0                             Zabour, Miss. Hileni
# 1305  1306       3         0                            Zabour, Miss. Thamine
# 1306  1307       3         0                        Zakarian, Mr. Mapriededer
# 1307  1308       3         0                              Zakarian, Mr. Ortin
# 1308  1309       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 15 columns]

# %%
# Writing Dataframe to a file

writer = ExcelWriter(titanic_positive_mismatch)
source_target_common_p.to_excel(writer, "Source_Target_Common")
writer.save()

# %%
# Source minus Target - Rows Available at 'Source' Which Are Not Available at 'Target'

source_minus_target_p = source_p.merge(target_p, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only'] 
source_minus_target_p
# Out:
# Empty DataFrame
# Columns: [pid, pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest, _merge]
# Index: []

# %%
# Writing Dataframe to a file

source_minus_target_p.to_excel(writer, "Source_minus_Target")
writer.save()

# %%
# Target minus Source - Rows Available at 'Target' Which Are Not Available at 'Source'

target_minus_source_p = source_p.merge(target_p, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='right_only']
target_minus_source_p
# Out:
# Empty DataFrame
# Columns: [pid, pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest, _merge]
# Index: []

# %%
# Writing Dataframe to a file

target_minus_source_p.to_excel(writer, "Target_minus_Source")
writer.save()

# %%
# Rows which are not common between 'Source' & 'Target'

source_target_not_common_p = pd.concat([source_p,target_p]).drop_duplicates(keep=False)
source_target_not_common_p
# Out:
# Empty DataFrame
# Columns: [pid, pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
# Writing Dataframe to a file

source_target_not_common_p.to_excel(writer, "Source_Target_not_common")
writer.save()

# %%
# Titanic Negative Case - With some Mismatch Records

titanic_negative_source = "D:\\Projects\\Cadent\\Cadent_BigDataTesting_Automation\\Demo\\Script_without_UDF\\Data_Files\\Titanic\\Titanic_Input\\Titanic_NegativeCase_Source.xls"
titanic_negative_target = "D:\\Projects\\Cadent\\Cadent_BigDataTesting_Automation\\Demo\\Script_without_UDF\\Data_Files\\Titanic\\Titanic_Input\\Titanic_NegativeCase_Target.xls"
titanic_negative_mismatch = "D:\\Projects\\Cadent\\Cadent_BigDataTesting_Automation\\Demo\\Script_without_UDF\\Data_Files\\Titanic\\Titanic_Output\\Titanic_NegativeCase_Mismatch.xls"

# %%
# Reading 'Source' data

source_n = pd.read_excel(titanic_negative_source, sheet_name = 'titanic')
print(source_n)
# Out:
#        pid  pclass  survived  \
# 0       21       1         1
# 1       22       1         1
# 2       23       1         1
# 3       24       1         1
# 4       25       1         1
# ...    ...     ...       ...
# 1284  1305       3         0
# 1285  1306       3         0
# 1286  1307       3         0
# 1287  1308       3         0
# 1288  1309       3         0
#
#                                                   name     sex   age  sibsp  \
# 0                        Beckwith, Mr. Richard Leonard    male  37.0      1
# 1     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 2                                Behr, Mr. Karl Howell    male  26.0      0
# 3                                Bidois, Miss. Rosalie  female  42.0      0
# 4                                    Bird, Miss. Ellen  female  29.0      0
# ...                                                ...     ...   ...    ...
# 1284                              Zabour, Miss. Hileni  female  14.5      1
# 1285                             Zabour, Miss. Thamine  female   NaN      1
# 1286                         Zakarian, Mr. Mapriededer    male  26.5      0
# 1287                               Zakarian, Mr. Ortin    male  27.0      0
# 1288                                Zimmerman, Mr. Leo    male  29.0      0
#
#       parch    ticket      fare cabin embarked boat   body     home.dest
# 0         1     11751   52.5542   D35        S    5    NaN  New York, NY
# 1         1     11751   52.5542   D35        S    5    NaN  New York, NY
# 2         0    111369   30.0000  C148        C    5    NaN  New York, NY
# 3         0  PC 17757  227.5250   NaN        C    4    NaN           NaN
# 4         0  PC 17483  221.7792   C97        S    8    NaN           NaN
# ...     ...       ...       ...   ...      ...  ...    ...           ...
# 1284      0      2665   14.4542   NaN        C  NaN  328.0           NaN
# 1285      0      2665   14.4542   NaN        C  NaN    NaN           NaN
# 1286      0      2656    7.2250   NaN        C  NaN  304.0           NaN
# 1287      0      2670    7.2250   NaN        C  NaN    NaN           NaN
# 1288      0    315082    7.8750   NaN        S  NaN    NaN           NaN
#
# [1289 rows x 15 columns]

# %%
# Reading 'Target' data

target_n = pd.read_excel(titanic_negative_target, sheet_name = 'titanic')
print(target_n)
# Out:
#        pid  pclass  survived                                             name  \
# 0        1       1         1                    Allen, Miss. Elisabeth Walton
# 1        2       1         1                   Allison, Master. Hudson Trevor
# 2        3       1         0                     Allison, Miss. Helen Loraine
# 3        4       1         0             Allison, Mr. Hudson Joshua Creighton
# 4        5       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...    ...     ...       ...                                              ...
# 1294  1295       3         0                             Williams, Mr. Leslie
# 1295  1296       3         0                              Windelov, Mr. Einar
# 1296  1297       3         0                                 Wirz, Mr. Albert
# 1297  1298       3         0                           Wiseman, Mr. Phillippe
# 1298  1299       3         0                        Wittevrongel, Mr. Camille
#
#          sex      age  sibsp  parch            ticket      fare    cabin  \
# 0     female  29.0000      0      0             24160  211.3375       B5
# 1       male   0.9167      1      2            113781  151.5500  C22 C26
# 2     female   2.0000      1      2            113781  151.5500  C22 C26
# 3       male  30.0000      1      2            113781  151.5500  C22 C26
# 4     female  25.0000      1      2            113781  151.5500  C22 C26
# ...      ...      ...    ...    ...               ...       ...      ...
# 1294    male  28.5000      0      0             54636   16.1000      NaN
# 1295    male  21.0000      0      0  SOTON/OQ 3101317    7.2500      NaN
# 1296    male  27.0000      0      0            315154    8.6625      NaN
# 1297    male      NaN      0      0        A/4. 34244    7.2500      NaN
# 1298    male  36.0000      0      0            345771    9.5000      NaN
#
#      embarked boat   body                        home.dest
# 0           S    2    NaN                     St Louis, MO
# 1           S   11    NaN  Montreal, PQ / Chesterville, ON
# 2           S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3           S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4           S  NaN    NaN  Montreal, PQ / Chesterville, ON
# ...       ...  ...    ...                              ...
# 1294        S  NaN   14.0                              NaN
# 1295        S  NaN    NaN                              NaN
# 1296        S  NaN  131.0                              NaN
# 1297        S  NaN    NaN                              NaN
# 1298        S  NaN    NaN                              NaN
#
# [1299 rows x 15 columns]

# %%
# Common Records accross Source & Target

source_target_common_n = source_n.merge(target_n, how = 'inner' ,indicator=False)
source_target_common_n
# Out:
#        pid  pclass  survived  \
# 0       21       1         1
# 1       22       1         1
# 2       23       1         1
# 3       24       1         1
# 4       25       1         1
# ...    ...     ...       ...
# 1274  1295       3         0
# 1275  1296       3         0
# 1276  1297       3         0
# 1277  1298       3         0
# 1278  1299       3         0
#
#                                                   name     sex   age  sibsp  \
# 0                        Beckwith, Mr. Richard Leonard    male  37.0      1
# 1     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 2                                Behr, Mr. Karl Howell    male  26.0      0
# 3                                Bidois, Miss. Rosalie  female  42.0      0
# 4                                    Bird, Miss. Ellen  female  29.0      0
# ...                                                ...     ...   ...    ...
# 1274                              Williams, Mr. Leslie    male  28.5      0
# 1275                               Windelov, Mr. Einar    male  21.0      0
# 1276                                  Wirz, Mr. Albert    male  27.0      0
# 1277                            Wiseman, Mr. Phillippe    male   NaN      0
# 1278                         Wittevrongel, Mr. Camille    male  36.0      0
#
#       parch            ticket      fare cabin embarked boat   body  \
# 0         1             11751   52.5542   D35        S    5    NaN
# 1         1             11751   52.5542   D35        S    5    NaN
# 2         0            111369   30.0000  C148        C    5    NaN
# 3         0          PC 17757  227.5250   NaN        C    4    NaN
# 4         0          PC 17483  221.7792   C97        S    8    NaN
# ...     ...               ...       ...   ...      ...  ...    ...
# 1274      0             54636   16.1000   NaN        S  NaN   14.0
# 1275      0  SOTON/OQ 3101317    7.2500   NaN        S  NaN    NaN
# 1276      0            315154    8.6625   NaN        S  NaN  131.0
# 1277      0        A/4. 34244    7.2500   NaN        S  NaN    NaN
# 1278      0            345771    9.5000   NaN        S  NaN    NaN
#
#          home.dest
# 0     New York, NY
# 1     New York, NY
# 2     New York, NY
# 3              NaN
# 4              NaN
# ...            ...
# 1274           NaN
# 1275           NaN
# 1276           NaN
# 1277           NaN
# 1278           NaN
#
# [1279 rows x 15 columns]

# %%
# Writing Dataframe to a file

writer = ExcelWriter(titanic_negative_mismatch)
source_target_common_n.to_excel(writer, "Source_Target_Common")
writer.save()

# %%
# Source minus Target - Rows Available at 'Source' Which Are Not Available at 'Target'

source_minus_target_n = source_n.merge(target_n, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only'] 
source_minus_target_n
# Out:
#        pid  pclass  survived                                     name     sex  \
# 1279  1300       3         0                      Yasbeck, Mr. Antoni    male
# 1280  1301       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1281  1302       3         0                     Youseff, Mr. Gerious    male
# 1282  1303       3         0                        Yousif, Mr. Wazli    male
# 1283  1304       3         0                    Yousseff, Mr. Gerious    male
# 1284  1305       3         0                     Zabour, Miss. Hileni  female
# 1285  1306       3         0                    Zabour, Miss. Thamine  female
# 1286  1307       3         0                Zakarian, Mr. Mapriededer    male
# 1287  1308       3         0                      Zakarian, Mr. Ortin    male
# 1288  1309       3         0                       Zimmerman, Mr. Leo    male
#
#        age  sibsp  parch  ticket     fare cabin embarked boat   body  \
# 1279  27.0      1      0    2659  14.4542   NaN        C    C    NaN
# 1280  15.0      1      0    2659  14.4542   NaN        C  NaN    NaN
# 1281  45.5      0      0    2628   7.2250   NaN        C  NaN  312.0
# 1282   NaN      0      0    2647   7.2250   NaN        C  NaN    NaN
# 1283   NaN      0      0    2627  14.4583   NaN        C  NaN    NaN
# 1284  14.5      1      0    2665  14.4542   NaN        C  NaN  328.0
# 1285   NaN      1      0    2665  14.4542   NaN        C  NaN    NaN
# 1286  26.5      0      0    2656   7.2250   NaN        C  NaN  304.0
# 1287  27.0      0      0    2670   7.2250   NaN        C  NaN    NaN
# 1288  29.0      0      0  315082   7.8750   NaN        S  NaN    NaN
#
#      home.dest     _merge
# 1279       NaN  left_only
# 1280       NaN  left_only
# 1281       NaN  left_only
# 1282       NaN  left_only
# 1283       NaN  left_only
# 1284       NaN  left_only
# 1285       NaN  left_only
# 1286       NaN  left_only
# 1287       NaN  left_only
# 1288       NaN  left_only

# %%
# Writing Dataframe to a file

source_minus_target_n.to_excel(writer, "Source_minus_Target")
writer.save()

# %%
# Target minus Source - Rows Available at 'Target' Which Are Not Available at 'Source'

target_minus_source_n = source_n.merge(target_n, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='right_only']
target_minus_source_n
# Out:
#       pid  pclass  survived  \
# 1289    1       1         1
# 1290    2       1         1
# 1291    3       1         0
# 1292    4       1         0
# 1293    5       1         0
# 1294    6       1         1
# 1295    7       1         1
# 1296    8       1         0
# 1297    9       1         1
# 1298   10       1         0
# 1299   11       1         0
# 1300   12       1         1
# 1301   13       1         1
# 1302   14       1         1
# 1303   15       1         1
# 1304   16       1         0
# 1305   17       1         0
# 1306   18       1         1
# 1307   19       1         1
# 1308   20       1         0
#
#                                                    name     sex      age  \
# 1289                      Allen, Miss. Elisabeth Walton  female  29.0000
# 1290                     Allison, Master. Hudson Trevor    male   0.9167
# 1291                       Allison, Miss. Helen Loraine  female   2.0000
# 1292               Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 1293    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 1294                                Anderson, Mr. Harry    male  48.0000
# 1295                  Andrews, Miss. Kornelia Theodosia  female  63.0000
# 1296                             Andrews, Mr. Thomas Jr    male  39.0000
# 1297      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 1298                            Artagaveytia, Mr. Ramon    male  71.0000
# 1299                             Astor, Col. John Jacob    male  47.0000
# 1300  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0000
# 1301                      Aubart, Mme. Leontine Pauline  female  24.0000
# 1302                       Barber, Miss. Ellen "Nellie"  female  26.0000
# 1303               Barkworth, Mr. Algernon Henry Wilson    male  80.0000
# 1304                                Baumann, Mr. John D    male      NaN
# 1305                           Baxter, Mr. Quigg Edmond    male  24.0000
# 1306    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0000
# 1307                              Bazzani, Miss. Albina  female  32.0000
# 1308                               Beattie, Mr. Thomson    male  36.0000
#
#       sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1289      0      0     24160  211.3375       B5        S    2    NaN
# 1290      1      2    113781  151.5500  C22 C26        S   11    NaN
# 1291      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 1292      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 1293      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 1294      0      0     19952   26.5500      E12        S    3    NaN
# 1295      1      0     13502   77.9583       D7        S   10    NaN
# 1296      0      0    112050    0.0000      A36        S  NaN    NaN
# 1297      2      0     11769   51.4792     C101        S    D    NaN
# 1298      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
# 1299      1      0  PC 17757  227.5250  C62 C64        C  NaN  124.0
# 1300      1      0  PC 17757  227.5250  C62 C64        C    4    NaN
# 1301      0      0  PC 17477   69.3000      B35        C    9    NaN
# 1302      0      0     19877   78.8500      NaN        S    6    NaN
# 1303      0      0     27042   30.0000      A23        S    B    NaN
# 1304      0      0  PC 17318   25.9250      NaN        S  NaN    NaN
# 1305      0      1  PC 17558  247.5208  B58 B60        C  NaN    NaN
# 1306      0      1  PC 17558  247.5208  B58 B60        C    6    NaN
# 1307      0      0     11813   76.2917      D15        C    8    NaN
# 1308      0      0     13050   75.2417       C6        C    A    NaN
#
#                             home.dest      _merge
# 1289                     St Louis, MO  right_only
# 1290  Montreal, PQ / Chesterville, ON  right_only
# 1291  Montreal, PQ / Chesterville, ON  right_only
# 1292  Montreal, PQ / Chesterville, ON  right_only
# 1293  Montreal, PQ / Chesterville, ON  right_only
# 1294                     New York, NY  right_only
# 1295                       Hudson, NY  right_only
# 1296                      Belfast, NI  right_only
# 1297              Bayside, Queens, NY  right_only
# 1298              Montevideo, Uruguay  right_only
# 1299                     New York, NY  right_only
# 1300                     New York, NY  right_only
# 1301                    Paris, France  right_only
# 1302                              NaN  right_only
# 1303                    Hessle, Yorks  right_only
# 1304                     New York, NY  right_only
# 1305                     Montreal, PQ  right_only
# 1306                     Montreal, PQ  right_only
# 1307                              NaN  right_only
# 1308                     Winnipeg, MN  right_only

# %%
# Writing Dataframe to a file

target_minus_source_n.to_excel(writer, "Target_minus_Source")
writer.save()

# %%
# Rows which are not common between 'Source' & 'Target'

source_target_not_common_n = pd.concat([source_n,target_n]).drop_duplicates(keep=False)
source_target_not_common_n
# Out:
#        pid  pclass  survived  \
# 1279  1300       3         0
# 1280  1301       3         1
# 1281  1302       3         0
# 1282  1303       3         0
# 1283  1304       3         0
# 1284  1305       3         0
# 1285  1306       3         0
# 1286  1307       3         0
# 1287  1308       3         0
# 1288  1309       3         0
# 0        1       1         1
# 1        2       1         1
# 2        3       1         0
# 3        4       1         0
# 4        5       1         0
# 5        6       1         1
# 6        7       1         1
# 7        8       1         0
# 8        9       1         1
# 9       10       1         0
# 10      11       1         0
# 11      12       1         1
# 12      13       1         1
# 13      14       1         1
# 14      15       1         1
# 15      16       1         0
# 16      17       1         0
# 17      18       1         1
# 18      19       1         1
# 19      20       1         0
#
#                                                    name     sex      age  \
# 1279                                Yasbeck, Mr. Antoni    male  27.0000
# 1280            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0000
# 1281                               Youseff, Mr. Gerious    male  45.5000
# 1282                                  Yousif, Mr. Wazli    male      NaN
# 1283                              Yousseff, Mr. Gerious    male      NaN
# 1284                               Zabour, Miss. Hileni  female  14.5000
# 1285                              Zabour, Miss. Thamine  female      NaN
# 1286                          Zakarian, Mr. Mapriededer    male  26.5000
# 1287                                Zakarian, Mr. Ortin    male  27.0000
# 1288                                 Zimmerman, Mr. Leo    male  29.0000
# 0                         Allen, Miss. Elisabeth Walton  female  29.0000
# 1                        Allison, Master. Hudson Trevor    male   0.9167
# 2                          Allison, Miss. Helen Loraine  female   2.0000
# 3                  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5                                   Anderson, Mr. Harry    male  48.0000
# 6                     Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7                                Andrews, Mr. Thomas Jr    male  39.0000
# 8         Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 9                               Artagaveytia, Mr. Ramon    male  71.0000
# 10                               Astor, Col. John Jacob    male  47.0000
# 11    Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0000
# 12                        Aubart, Mme. Leontine Pauline  female  24.0000
# 13                         Barber, Miss. Ellen "Nellie"  female  26.0000
# 14                 Barkworth, Mr. Algernon Henry Wilson    male  80.0000
# 15                                  Baumann, Mr. John D    male      NaN
# 16                             Baxter, Mr. Quigg Edmond    male  24.0000
# 17      Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0000
# 18                                Bazzani, Miss. Albina  female  32.0000
# 19                                 Beattie, Mr. Thomson    male  36.0000
#
#       sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1279      1      0      2659   14.4542      NaN        C    C    NaN
# 1280      1      0      2659   14.4542      NaN        C  NaN    NaN
# 1281      0      0      2628    7.2250      NaN        C  NaN  312.0
# 1282      0      0      2647    7.2250      NaN        C  NaN    NaN
# 1283      0      0      2627   14.4583      NaN        C  NaN    NaN
# 1284      1      0      2665   14.4542      NaN        C  NaN  328.0
# 1285      1      0      2665   14.4542      NaN        C  NaN    NaN
# 1286      0      0      2656    7.2250      NaN        C  NaN  304.0
# 1287      0      0      2670    7.2250      NaN        C  NaN    NaN
# 1288      0      0    315082    7.8750      NaN        S  NaN    NaN
# 0         0      0     24160  211.3375       B5        S    2    NaN
# 1         1      2    113781  151.5500  C22 C26        S   11    NaN
# 2         1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 3         1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4         1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5         0      0     19952   26.5500      E12        S    3    NaN
# 6         1      0     13502   77.9583       D7        S   10    NaN
# 7         0      0    112050    0.0000      A36        S  NaN    NaN
# 8         2      0     11769   51.4792     C101        S    D    NaN
# 9         0      0  PC 17609   49.5042      NaN        C  NaN   22.0
# 10        1      0  PC 17757  227.5250  C62 C64        C  NaN  124.0
# 11        1      0  PC 17757  227.5250  C62 C64        C    4    NaN
# 12        0      0  PC 17477   69.3000      B35        C    9    NaN
# 13        0      0     19877   78.8500      NaN        S    6    NaN
# 14        0      0     27042   30.0000      A23        S    B    NaN
# 15        0      0  PC 17318   25.9250      NaN        S  NaN    NaN
# 16        0      1  PC 17558  247.5208  B58 B60        C  NaN    NaN
# 17        0      1  PC 17558  247.5208  B58 B60        C    6    NaN
# 18        0      0     11813   76.2917      D15        C    8    NaN
# 19        0      0     13050   75.2417       C6        C    A    NaN
#
#                             home.dest
# 1279                              NaN
# 1280                              NaN
# 1281                              NaN
# 1282                              NaN
# 1283                              NaN
# 1284                              NaN
# 1285                              NaN
# 1286                              NaN
# 1287                              NaN
# 1288                              NaN
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# 5                        New York, NY
# 6                          Hudson, NY
# 7                         Belfast, NI
# 8                 Bayside, Queens, NY
# 9                 Montevideo, Uruguay
# 10                       New York, NY
# 11                       New York, NY
# 12                      Paris, France
# 13                                NaN
# 14                      Hessle, Yorks
# 15                       New York, NY
# 16                       Montreal, PQ
# 17                       Montreal, PQ
# 18                                NaN
# 19                       Winnipeg, MN

# %%
# Writing Dataframe to a file

source_target_not_common_n.to_excel(writer, "Source_Target_not_common")
writer.save()
